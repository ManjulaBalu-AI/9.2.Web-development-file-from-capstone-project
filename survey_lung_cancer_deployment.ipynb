# %%
import pickle

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
X_df = pd.read_csv('survey lung cancer.csv')

# %%
X_df = pd.get_dummies(X_df, drop_first=True,dtype=int)

# %%
X_df
# Out:
#      AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  \
# 0     69        1               2        2              1                1
# 1     74        2               1        1              1                2
# 2     59        1               1        1              2                1
# 3     63        2               2        2              1                1
# 4     63        1               2        1              1                1
# ..   ...      ...             ...      ...            ...              ...
# 304   56        1               1        1              2                2
# 305   70        2               1        1              1                1
# 306   58        2               1        1              1                1
# 307   67        2               1        2              1                1
# 308   62        1               1        1              2                1
#
#      FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0           2         1         2                  2         2
# 1           2         2         1                  1         1
# 2           2         1         2                  1         2
# 3           1         1         1                  2         1
# 4           1         1         2                  1         2
# ..        ...       ...       ...                ...       ...
# 304         2         1         1                  2         2
# 305         2         2         2                  2         2
# 306         1         2         2                  2         2
# 307         2         2         1                  2         2
# 308         2         2         2                  2         1
#
#      SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  GENDER_M  \
# 0                      2                      2           2         1
# 1                      2                      2           2         1
# 2                      2                      1           2         0
# 3                      1                      2           2         1
# 4                      2                      1           1         0
# ..                   ...                    ...         ...       ...
# 304                    2                      2           1         0
# 305                    2                      1           2         1
# 306                    1                      1           2         1
# 307                    2                      1           2         1
# 308                    1                      2           1         1
#
#      LUNG_CANCER_YES
# 0                  1
# 1                  1
# 2                  0
# 3                  0
# 4                  0
# ..               ...
# 304                1
# 305                1
# 306                1
# 307                1
# 308                1
#
# [309 rows x 16 columns]

# %%
y = X_df["LUNG_CANCER_YES"]

# %%
indep=X_df[['ALLERGY ', 'WHEEZING', 'ALCOHOL CONSUMING', 'COUGHING', 'SWALLOWING DIFFICULTY']]
dep=X_df['LUNG_CANCER_YES']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
preinput_data = [[2, 2, 1, 2, 1]]

# %%
preinput = sc.transform(preinput_data)
# Out:
# C:\Users\Admin\anaconda3\envs\aids\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"

# %%
preinput
# Out:
# array([[ 0.92512478,  0.86357554, -1.15797629,  0.81319759, -0.96189066]])

# %%
loaded_model=pickle.load(open("Lung_cancer_5feature_model.sav",'rb'))
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([1])
